# %% [markdown]
# <a href="https://colab.research.google.com/github/sahil0078sharma-oss/Py-Practice/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/sahil0078sharma-oss/Python-ML/refs/heads/main/file.csv"

df = pd.read_csv(url)

print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
import pandas as pd

url = "https://github.com/sahil0078sharma-oss/Python-ML/raw/refs/heads/main/file.xlsx"

df = pd.read_excel(url)

print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/sahil0078sharma-oss/Python-ML/refs/heads/main/data.json"

df = pd.read_json(url)

print(df)
# Out:
#        name  age
# 0    nikhil   10
# 1  devendra   20
# 2       raj   30
# 3     hello   40
