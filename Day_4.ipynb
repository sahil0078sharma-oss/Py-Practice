# %% [markdown]
# <a href="https://colab.research.google.com/github/sahil0078sharma-oss/Py-Practice/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Sahil Sharma")
# Out:
# Sahil Sharma

# %%
# Methods of list
# 1-append()
arr = [10,20,30]

arr.append(50)

print(arr)
# Out:
# [10, 20, 30, 50]

# %%
#2 insert()
arr = [10,20,30]
arr.insert(1,100)

print(arr)
# Out:
# [10, 100, 20, 30]

# %%
#3 length

arr = [10,20,30]

arr.
