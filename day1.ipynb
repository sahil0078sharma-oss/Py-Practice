# %% [markdown]
# <a href="https://colab.research.google.com/github/sahil0078sharma-oss/Py-Practice/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("sahil sharma")
# Out:
# sahil sharma
